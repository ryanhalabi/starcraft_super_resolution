# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanhalabi/starcraft_super_resolution/blob/master/super_resolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import os
import re 
import keras
import cv2
import numpy as np
import uuid
import shutil
import os
from pathlib import Path
from google.colab import drive
import tensorflow as tf

# %tensorflow_version 2.x
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))


drive.mount('/content/drive')
print(os.getcwd())
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# TensorFlow is already loaded. Please restart the runtime to change versions.
# Found GPU at: /device:GPU:0
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content

# %%
class Environment(object):

  def __init__(self):
    pwd = Path(os.getcwd())
    print(pwd)
    if not os.path.isdir(pwd / 'drive' / 'My Drive' / 'super_res'):
      # shutil.rmtree(pwd / 'drive' / 'My Drive' / 'super_res' )
      os.mkdir( pwd / 'drive' / 'My Drive' / 'super_res'   )
      os.mkdir( pwd / 'drive' / 'My Drive' / 'super_res' / 'source'   )
      os.mkdir( pwd / 'drive' / 'My Drive' / 'super_res' / 'models' )
      os.mkdir( pwd / 'drive' / 'My Drive' / 'super_res' / 'model_output' )

    self.path = pwd / 'drive' / 'My Drive' / 'super_res'

env = Environment()



def download_images(urls):
  for url in urls:
      unit = re.search( r"[/\d]([\w]*).png", url).group(1)
      file_name = str(env.path / 'source' / f"{unit}.png")
      with open(file_name,'wb+') as f:
          f.write(requests.get(url).content)
# Out:
# /content

# %%
class Image:

    def __init__(self, path, greyscale):
        self.path = path
        self.greyscale = greyscale
        self.read_type = cv2.IMREAD_GRAYSCALE if greyscale else cv2.IMREAD_COLOR

    @property
    def name(self):
        return re.search( r"/([\w]*).png", str(self.path)).group(1)

    def get_array(self, scale=1):
        array = cv2.imread(str(self.path) , self.read_type)
        if scale != 1:
            array = cv2.resize(array, (int(array.shape[0]/scale), int(array.shape[1]/scale)))
        if self.greyscale:
            array = np.expand_dims(array,2)
        return array

# %%
class Model:

    def __init__(self, name, scaling=5, channels=1, conv_size=9):
        self.name = name
        self.scaling = scaling
        self.channels = channels
        self.conv_size = conv_size

        # scaling x the pixels, (conv_size - scaling)/2 extra pixels get added on each side as padding from conv2dtranspose
        # we dont care about these pixels for comparing against target
        # we also dont care about the pixels influenced by these extra pixels
        # get rid of depad filter of size 
        # (conv_size - scaling + 1) - gets rid of pad pixels
        # (conv_size+1) - gets rid of pixels influenced by padded pixels
        # so get rid of 2*conv_size - scaling pixels total

        # ex, 5x, conv 9
        # 0 0 x x X x+y x+y Y y+w y+w W
        # 18 - 5 = 13 = gets rid of 6 pixels each side
        # im probably fucking this up since further conv layers increase the impact of pixels
        # oh well

        self.set_optimizer()

        if not os.path.isdir(env.path / 'model_output' / self.name):
            os.mkdir( env.path / 'model_output' / self.name )
        for file in os.listdir( env.path / 'model_output' / self.name):
          os.remove(  env.path / 'model_output' / self.name / file)
        

        if os.path.isfile(env.path / 'models' / f"{name}.hdf5"):
            self.model = keras.models.load_model( str(env.path / 'models' / f"{name}.hdf5"))
        else:


            inputs = keras.layers.Input(shape=(100, 100, self.channels))
            upscaler = keras.layers.Conv2DTranspose(self.channels, (self.conv_size, self.conv_size), strides=(self.scaling,self.scaling))(inputs)

            conv_1 = keras.layers.Conv2D(64, (9,9), strides=(1,1), padding='same', activation='relu')(upscaler)
            conv_2 = keras.layers.Conv2D(32, (1,1), strides=(1,1), padding='same', activation='relu')(conv_1)
            conv_3 = keras.layers.Conv2D(self.channels, (5,5), strides=(1,1), padding='same')(conv_2)
            
            add_layer = keras.layers.add([conv_3, upscaler])

            depad_filter_size = 2*self.conv_size - self.scaling
            depad_kernel = np.zeros([depad_filter_size, depad_filter_size, self.channels, self.channels])
            center = int(depad_kernel.shape[0]/2)
            for i in range(self.channels):
              depad_kernel[center, center,i,i] = 1

            depad_bias = np.zeros([self.channels])

            predictions = keras.layers.Conv2D(self.channels, (depad_filter_size, depad_filter_size), strides=(1,1),
                                            weights=[depad_kernel, depad_bias], trainable=False)(add_layer)
            # predictions = keras.layers.Conv2D(self.channels, (depad_filter_size, depad_filter_size), strides=(1,1))(add_layer)

            model = keras.Model(inputs=inputs, outputs=predictions)

            model.compile(self.optimizer, 'mean_squared_error')

            self.model = model


    def set_optimizer(self):
        self.optimizer = keras.optimizers.Adam()


    def save_model(self):
        self.model.save( str(env.path / 'models' / f"{self.model.name}.hdf5"))

# %%
class TrainSRModel:

    def __init__(self, model, save=False):
        self.model = model
        self.save = save

        self.set_up_model()

    def set_up_model(self):
        up_model = keras.Sequential()
        up_model.add(keras.layers.UpSampling2D(size=(self.model.scaling,self.model.scaling), interpolation='bilinear', input_shape=(None, None, self.model.channels)))
        self.up_model = up_model


    def train(self, images, epochs, save):
        train_images = images

        self.X = np.array([x.get_array(self.model.scaling) for x in train_images])

        y = [x.get_array() for x in train_images]
        padding = int((self.model.conv_size-1)/2)
        y = [x[padding:-padding, padding:-padding,:] for x in y]
        self.Y = np.array(y)

        self.save_initial(images)

        for i in range(epochs):
            self.model.model.fit(self.X, self.Y, epochs = save, verbose=1) 
            print(f"Epoch {i} Loss: {self.model.model.history.history['loss'][-1]}")
            self.predict(images, i)
        self.predict(images, '0_final')

        if self.save:
            self.model.save(f"{self.model.name}.hdf5")

    def predict(self, images, name):

        x = np.array([x.get_array(self.model.scaling) for x in images])
        image_names = [x.name for x in images]

        preds = self.model.model.predict(x)

        for j, pred in enumerate(preds):
            cv2.imwrite( str(env.path / 'model_output' / self.model.name / f"{image_names[j]}_{name}.png"), pred)
        return preds



    def save_initial(self, images):

        image_names = [x.name for x in images]

        y = [x.get_array() for x in images]
        padding = int((self.model.conv_size-1)/2)
        y = [x[padding:-padding, padding:-padding,:] for x in y]
        Y = np.array(y)

        for j, y in enumerate(Y):
            cv2.imwrite( str(env.path / 'model_output' / self.model.name / f"{image_names[j]}.png"), y)

        X = np.array([x.get_array(self.model.scaling) for x in images])

        up_samples = self.up_model.predict(X)
        padding = int((self.model.conv_size-1)/2)
        up_samples = [x[padding:-padding, padding:-padding,:] for x in up_samples]

        for j, up_sample in enumerate(up_samples):
            cv2.imwrite( str(env.path / 'model_output' / self.model.name / f"{image_names[j]}_0_upscaled.png"), up_sample)




    # def plot_filters(self):

    #     weights = self.model.weights
    #     for weight in weights:
    #         for i in range( weight.shape[2]):
    #             filter = weight[:,:,i,0]
    #             plt.plot(filter)
    #             plt.show()

# %%
image_urls = [
                "https://liquipedia.net/commons/images/9/9d/Marine.png",
                "https://liquipedia.net/commons/images/8/8a/Firebat.png",
                "https://liquipedia.net/commons/images/2/26/Medic.png",
                "https://liquipedia.net/commons/images/f/f7/Scv.png",
                "https://liquipedia.net/commons/images/a/ab/Ghost.png",
                # "https://liquipedia.net/commons/images/thumb/1/13/%24Academy.png/600px-%24Academy.png",
                # "https://liquipedia.net/commons/images/thumb/d/dd/%24Armory.png/600px-%24Armory.png",
                # "https://liquipedia.net/commons/images/thumb/d/df/%24Barracks.png/600px-%24Barracks.png",
                # "https://liquipedia.net/commons/images/thumb/e/e9/%24Bunker.png/600px-%24Bunker.png",
                # "https://liquipedia.net/commons/images/thumb/d/dc/%24Command_Center.png/600px-%24Command_Center.png",
                # "https://liquipedia.net/commons/images/thumb/1/1f/%24Comsat_Station.png/600px-%24Comsat_Station.png",
                # "https://liquipedia.net/commons/images/thumb/2/2b/%24Control_Tower.png/600px-%24Control_Tower.png",
                # "https://liquipedia.net/commons/images/thumb/0/04/%24Covert_Ops.png/600px-%24Covert_Ops.png",
                # "https://liquipedia.net/commons/images/thumb/4/41/%24Engineering_Bay.png/600px-%24Engineering_Bay.png",
                # "https://liquipedia.net/commons/images/thumb/3/36/%24Factory.png/600px-%24Factory.png",
                # "https://liquipedia.net/commons/images/thumb/0/0b/%24Machine_Shop.png/600px-%24Machine_Shop.png",
                # "https://liquipedia.net/commons/images/thumb/4/41/%24Missile_Turret.png/600px-%24Missile_Turret.png",
                # "https://liquipedia.net/commons/images/thumb/e/ed/%24Nuclear_Silo.png/600px-%24Nuclear_Silo.png",
                # "https://liquipedia.net/commons/images/thumb/7/7a/%24Physics_Lab.png/600px-%24Physics_Lab.png",
                # "https://liquipedia.net/commons/images/thumb/c/ce/%24Refinery.png/600px-%24Refinery.png",
                # "https://liquipedia.net/commons/images/thumb/2/25/%24Science_Facility.png/600px-%24Science_Facility.png",
                # "https://liquipedia.net/commons/images/thumb/2/24/%24Starport.png/600px-%24Starport.png",
                # "https://liquipedia.net/commons/images/thumb/c/c7/%24Supply_Depot.png/600px-%24Supply_Depot.png"
                ]

download_images(image_urls)


images = [Image( env.path / 'source' / x, greyscale=False) for x in os.listdir(env.path / "source")]
model = Model('test_color',channels=3)

mt = TrainSRModel(model, False)


x = np.array([x.get_array(mt.model.scaling) for x in images])
image_names = [x.name for x in images]

mt.train(images, epochs=500, save=50)


# import matplotlib.pyplot as plt
# plt.matshow(mt.model.model.layers[0].get_weights()[0][:,:,0,0])
# plt.show()


# import numpy as np
# x = images[0].get_array(4)
# y = mt.model.predict( np.array([x]))
# # cv2.imwrite( str(env.path / 'images' / f"Atest.png"), x)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2241: The name tf.image.resize_bilinear is deprecated. Please use tf.compat.v1.image.resize_bilinear instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# 5/5 [==============================] - 4s 824ms/step - loss: 3938.6978
# Epoch 2/50
# 5/5 [==============================] - 0s 77ms/step - loss: 3573.4810
# Epoch 3/50
# 5/5 [==============================] - 0s 76ms/step - loss: 3232.8442
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 2871.5068
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 2471.5435
# Epoch 6/50
# 5/5 [==============================] - 0s 74ms/step - loss: 2029.4375
# Epoch 7/50
# 5/5 [==============================] - 0s 76ms/step - loss: 1552.2122
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 1069.4253
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 645.7274
# Epoch 10/50
# 5/5 [==============================] - 0s 74ms/step - loss: 395.1926
# Epoch 11/50
# 5/5 [==============================] - 0s 77ms/step - loss: 460.4016
# Epoch 12/50
# 5/5 [==============================] - 0s 74ms/step - loss: 748.6197
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 856.1232
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 720.0731
# Epoch 15/50
# 5/5 [==============================] - 0s 77ms/step - loss: 502.2760
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 330.7793
# Epoch 17/50
# 5/5 [==============================] - 0s 76ms/step - loss: 252.5350
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 254.0287
# Epoch 19/50
# 5/5 [==============================] - 0s 77ms/step - loss: 296.7187
# Epoch 20/50
# 5/5 [==============================] - 0s 74ms/step - loss: 344.7696
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 375.4114
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 379.3004
# Epoch 23/50
# 5/5 [==============================] - 0s 76ms/step - loss: 357.4399
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 317.3525
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 270.0536
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 227.4710
# Epoch 27/50
# 5/5 [==============================] - 0s 76ms/step - loss: 199.6667
# Epoch 28/50
# 5/5 [==============================] - 0s 74ms/step - loss: 191.6960
# Epoch 29/50
# 5/5 [==============================] - 0s 74ms/step - loss: 200.9955
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 217.6233
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 228.9842
# Epoch 32/50
# 5/5 [==============================] - 0s 74ms/step - loss: 226.8260
# Epoch 33/50
# 5/5 [==============================] - 0s 76ms/step - loss: 211.2835
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 189.2419
# Epoch 35/50
# 5/5 [==============================] - 0s 76ms/step - loss: 169.3745
# Epoch 36/50
# 5/5 [==============================] - 0s 74ms/step - loss: 157.5259
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 154.9500
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 159.0860
# Epoch 39/50
# 5/5 [==============================] - 0s 77ms/step - loss: 165.5872
# Epoch 40/50
# 5/5 [==============================] - 0s 74ms/step - loss: 170.4118
# Epoch 41/50
# 5/5 [==============================] - 0s 74ms/step - loss: 171.1501
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 167.3876
# Epoch 43/50
# 5/5 [==============================] - 0s 77ms/step - loss: 160.4490
# Epoch 44/50
# 5/5 [==============================] - 0s 74ms/step - loss: 152.6731
# Epoch 45/50
# 5/5 [==============================] - 0s 74ms/step - loss: 146.4493
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 143.3020
# Epoch 47/50
# 5/5 [==============================] - 0s 76ms/step - loss: 143.3372
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 145.2875
# Epoch 49/50
# 5/5 [==============================] - 0s 74ms/step - loss: 147.1986
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 147.4610
# Epoch 0 Loss: 147.4609832763672
# Epoch 1/50
# 5/5 [==============================] - 0s 73ms/step - loss: 145.6065
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 142.3947
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 139.2099
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 137.2287
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 136.8656
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 137.7186
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 138.9195
# Epoch 8/50
# 5/5 [==============================] - 0s 76ms/step - loss: 139.6208
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 139.3692
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 138.2342
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 136.6904
# Epoch 12/50
# 5/5 [==============================] - 0s 76ms/step - loss: 135.3420
# Epoch 13/50
# 5/5 [==============================] - 0s 74ms/step - loss: 134.6200
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 134.5936
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 134.9793
# Epoch 16/50
# 5/5 [==============================] - 0s 76ms/step - loss: 135.3369
# Epoch 17/50
# 5/5 [==============================] - 0s 74ms/step - loss: 135.3296
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 134.8949
# Epoch 19/50
# 5/5 [==============================] - 0s 74ms/step - loss: 134.2343
# Epoch 20/50
# 5/5 [==============================] - 0s 77ms/step - loss: 133.6525
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 133.3643
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 133.3877
# Epoch 23/50
# 5/5 [==============================] - 0s 76ms/step - loss: 133.5676
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 133.6902
# Epoch 25/50
# 5/5 [==============================] - 0s 74ms/step - loss: 133.6094
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 133.3147
# Epoch 27/50
# 5/5 [==============================] - 0s 77ms/step - loss: 132.9164
# Epoch 28/50
# 5/5 [==============================] - 0s 74ms/step - loss: 132.5672
# Epoch 29/50
# 5/5 [==============================] - 0s 74ms/step - loss: 132.3715
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 132.3331
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 132.3679
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 132.3690
# Epoch 33/50
# 5/5 [==============================] - 0s 74ms/step - loss: 132.2655
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 132.0688
# Epoch 35/50
# 5/5 [==============================] - 0s 77ms/step - loss: 131.8497
# Epoch 36/50
# 5/5 [==============================] - 0s 74ms/step - loss: 131.6763
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 131.5756
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 131.5241
# Epoch 39/50
# 5/5 [==============================] - 0s 78ms/step - loss: 131.4718
# Epoch 40/50
# 5/5 [==============================] - 0s 74ms/step - loss: 131.3785
# Epoch 41/50
# 5/5 [==============================] - 0s 76ms/step - loss: 131.2380
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 131.0778
# Epoch 43/50
# 5/5 [==============================] - 0s 76ms/step - loss: 130.9358
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 130.8337
# Epoch 45/50
# 5/5 [==============================] - 0s 77ms/step - loss: 130.7637
# Epoch 46/50
# 5/5 [==============================] - 0s 74ms/step - loss: 130.6974
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 130.6091
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 130.4940
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 130.3670
# Epoch 50/50
# 5/5 [==============================] - 0s 74ms/step - loss: 130.2491
# Epoch 0 Loss: 130.24905395507812
# Epoch 1/50
# 5/5 [==============================] - 0s 71ms/step - loss: 130.1507
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 130.0663
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 129.9815
# Epoch 4/50
# 5/5 [==============================] - 0s 76ms/step - loss: 129.8847
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 129.7759
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 129.6641
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 129.5598
# Epoch 8/50
# 5/5 [==============================] - 0s 77ms/step - loss: 129.4661
# Epoch 9/50
# 5/5 [==============================] - 0s 74ms/step - loss: 129.3773
# Epoch 10/50
# 5/5 [==============================] - 0s 78ms/step - loss: 129.2845
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 129.1820
# Epoch 12/50
# 5/5 [==============================] - 0s 76ms/step - loss: 129.0710
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 128.9570
# Epoch 14/50
# 5/5 [==============================] - 0s 74ms/step - loss: 128.8441
# Epoch 15/50
# 5/5 [==============================] - 0s 76ms/step - loss: 128.7322
# Epoch 16/50
# 5/5 [==============================] - 0s 77ms/step - loss: 128.6210
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 128.5120
# Epoch 18/50
# 5/5 [==============================] - 0s 74ms/step - loss: 128.4069
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 128.3062
# Epoch 20/50
# 5/5 [==============================] - 0s 76ms/step - loss: 128.2079
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 128.1087
# Epoch 22/50
# 5/5 [==============================] - 0s 74ms/step - loss: 128.0067
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.9020
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.7965
# Epoch 25/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.6917
# Epoch 26/50
# 5/5 [==============================] - 0s 76ms/step - loss: 127.5871
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.4818
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.3755
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.2690
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.1634
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 127.0588
# Epoch 32/50
# 5/5 [==============================] - 0s 76ms/step - loss: 126.9544
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.8496
# Epoch 34/50
# 5/5 [==============================] - 0s 74ms/step - loss: 126.7444
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.6396
# Epoch 36/50
# 5/5 [==============================] - 0s 76ms/step - loss: 126.5351
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.4304
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.3252
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.2195
# Epoch 40/50
# 5/5 [==============================] - 0s 76ms/step - loss: 126.1137
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 126.0082
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 125.9026
# Epoch 43/50
# 5/5 [==============================] - 0s 74ms/step - loss: 125.7966
# Epoch 44/50
# 5/5 [==============================] - 0s 77ms/step - loss: 125.6906
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 125.5846
# Epoch 46/50
# 5/5 [==============================] - 0s 77ms/step - loss: 125.4788
# Epoch 47/50
# 5/5 [==============================] - 0s 74ms/step - loss: 125.3732
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 125.2676
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 125.1622
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 125.0572
# Epoch 0 Loss: 125.05720520019531
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 124.9525
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.8479
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.7435
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.6394
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.5355
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.4320
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.3288
# Epoch 8/50
# 5/5 [==============================] - 0s 77ms/step - loss: 124.2260
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.1235
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 124.0216
# Epoch 11/50
# 5/5 [==============================] - 0s 74ms/step - loss: 123.9201
# Epoch 12/50
# 5/5 [==============================] - 0s 76ms/step - loss: 123.8190
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 123.7186
# Epoch 14/50
# 5/5 [==============================] - 0s 74ms/step - loss: 123.6187
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 123.5194
# Epoch 16/50
# 5/5 [==============================] - 0s 78ms/step - loss: 123.4205
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 123.3222
# Epoch 18/50
# 5/5 [==============================] - 0s 74ms/step - loss: 123.2245
# Epoch 19/50
# 5/5 [==============================] - 0s 74ms/step - loss: 123.1273
# Epoch 20/50
# 5/5 [==============================] - 0s 76ms/step - loss: 123.0306
# Epoch 21/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.9344
# Epoch 22/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.8389
# Epoch 23/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.7440
# Epoch 24/50
# 5/5 [==============================] - 0s 78ms/step - loss: 122.6498
# Epoch 25/50
# 5/5 [==============================] - 0s 75ms/step - loss: 122.5563
# Epoch 26/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.4635
# Epoch 27/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.3714
# Epoch 28/50
# 5/5 [==============================] - 0s 76ms/step - loss: 122.2801
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 122.1895
# Epoch 30/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.0995
# Epoch 31/50
# 5/5 [==============================] - 0s 74ms/step - loss: 122.0102
# Epoch 32/50
# 5/5 [==============================] - 0s 79ms/step - loss: 121.9215
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 121.8334
# Epoch 34/50
# 5/5 [==============================] - 0s 74ms/step - loss: 121.7459
# Epoch 35/50
# 5/5 [==============================] - 0s 74ms/step - loss: 121.6590
# Epoch 36/50
# 5/5 [==============================] - 0s 78ms/step - loss: 121.5725
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 121.4865
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 121.4009
# Epoch 39/50
# 5/5 [==============================] - 0s 74ms/step - loss: 121.3159
# Epoch 40/50
# 5/5 [==============================] - 0s 76ms/step - loss: 121.2316
# Epoch 41/50
# 5/5 [==============================] - 0s 76ms/step - loss: 121.1479
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 121.0648
# Epoch 43/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.9821
# Epoch 44/50
# 5/5 [==============================] - 0s 76ms/step - loss: 120.8999
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.8184
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.7377
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.6580
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 120.5799
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.5033
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.4282
# Epoch 0 Loss: 120.4282455444336
# Epoch 1/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.3549
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.2834
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.2135
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.1450
# Epoch 5/50
# 5/5 [==============================] - 0s 77ms/step - loss: 120.0776
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 120.0113
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.9461
# Epoch 8/50
# 5/5 [==============================] - 0s 74ms/step - loss: 119.8820
# Epoch 9/50
# 5/5 [==============================] - 0s 78ms/step - loss: 119.8188
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.7566
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.6954
# Epoch 12/50
# 5/5 [==============================] - 0s 74ms/step - loss: 119.6350
# Epoch 13/50
# 5/5 [==============================] - 0s 78ms/step - loss: 119.5754
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.5167
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.4588
# Epoch 16/50
# 5/5 [==============================] - 0s 76ms/step - loss: 119.4019
# Epoch 17/50
# 5/5 [==============================] - 0s 78ms/step - loss: 119.3458
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.2905
# Epoch 19/50
# 5/5 [==============================] - 0s 77ms/step - loss: 119.2359
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.1819
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.1286
# Epoch 22/50
# 5/5 [==============================] - 0s 74ms/step - loss: 119.0760
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 119.0242
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.9731
# Epoch 25/50
# 5/5 [==============================] - 0s 77ms/step - loss: 118.9227
# Epoch 26/50
# 5/5 [==============================] - 0s 74ms/step - loss: 118.8730
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.8239
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.7756
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.7280
# Epoch 30/50
# 5/5 [==============================] - 0s 74ms/step - loss: 118.6811
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.6348
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.5890
# Epoch 33/50
# 5/5 [==============================] - 0s 77ms/step - loss: 118.5437
# Epoch 34/50
# 5/5 [==============================] - 0s 74ms/step - loss: 118.4988
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.4542
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.4099
# Epoch 37/50
# 5/5 [==============================] - 0s 78ms/step - loss: 118.3658
# Epoch 38/50
# 5/5 [==============================] - 0s 74ms/step - loss: 118.3219
# Epoch 39/50
# 5/5 [==============================] - 0s 74ms/step - loss: 118.2783
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.2349
# Epoch 41/50
# 5/5 [==============================] - 0s 78ms/step - loss: 118.1919
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.1492
# Epoch 43/50
# 5/5 [==============================] - 0s 75ms/step - loss: 118.1071
# Epoch 44/50
# 5/5 [==============================] - 0s 76ms/step - loss: 118.0659
# Epoch 45/50
# 5/5 [==============================] - 0s 78ms/step - loss: 118.0260
# Epoch 46/50
# 5/5 [==============================] - 0s 78ms/step - loss: 117.9874
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.9498
# Epoch 48/50
# 5/5 [==============================] - 0s 74ms/step - loss: 117.9130
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.8765
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.8402
# Epoch 0 Loss: 117.84017181396484
# Epoch 1/50
# 5/5 [==============================] - 0s 73ms/step - loss: 117.8039
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.7677
# Epoch 3/50
# 5/5 [==============================] - 0s 76ms/step - loss: 117.7316
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.6955
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.6596
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.6238
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.5882
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.5533
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.5188
# Epoch 10/50
# 5/5 [==============================] - 0s 76ms/step - loss: 117.4850
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.4517
# Epoch 12/50
# 5/5 [==============================] - 0s 77ms/step - loss: 117.4187
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.3861
# Epoch 14/50
# 5/5 [==============================] - 0s 76ms/step - loss: 117.3536
# Epoch 15/50
# 5/5 [==============================] - 0s 74ms/step - loss: 117.3214
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.2892
# Epoch 17/50
# 5/5 [==============================] - 0s 76ms/step - loss: 117.2571
# Epoch 18/50
# 5/5 [==============================] - 0s 77ms/step - loss: 117.2252
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.1934
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.1618
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.1304
# Epoch 22/50
# 5/5 [==============================] - 0s 77ms/step - loss: 117.0993
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 117.0684
# Epoch 24/50
# 5/5 [==============================] - 0s 74ms/step - loss: 117.0377
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 117.0072
# Epoch 26/50
# 5/5 [==============================] - 0s 77ms/step - loss: 116.9769
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.9468
# Epoch 28/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.9170
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.8873
# Epoch 30/50
# 5/5 [==============================] - 0s 76ms/step - loss: 116.8579
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.8287
# Epoch 32/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.7998
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.7710
# Epoch 34/50
# 5/5 [==============================] - 0s 78ms/step - loss: 116.7426
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.7143
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.6862
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.6582
# Epoch 38/50
# 5/5 [==============================] - 0s 76ms/step - loss: 116.6304
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.6028
# Epoch 40/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.5752
# Epoch 41/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.5478
# Epoch 42/50
# 5/5 [==============================] - 0s 78ms/step - loss: 116.5205
# Epoch 43/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.4933
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.4662
# Epoch 45/50
# 5/5 [==============================] - 0s 76ms/step - loss: 116.4391
# Epoch 46/50
# 5/5 [==============================] - 0s 78ms/step - loss: 116.4122
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.3854
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.3586
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.3319
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.3053
# Epoch 0 Loss: 116.3052749633789
# Epoch 1/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.2787
# Epoch 2/50
# 5/5 [==============================] - 0s 76ms/step - loss: 116.2522
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.2257
# Epoch 4/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.1992
# Epoch 5/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.1727
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.1463
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.1198
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.0935
# Epoch 9/50
# 5/5 [==============================] - 0s 74ms/step - loss: 116.0671
# Epoch 10/50
# 5/5 [==============================] - 0s 76ms/step - loss: 116.0408
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 116.0144
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.9881
# Epoch 13/50
# 5/5 [==============================] - 0s 74ms/step - loss: 115.9618
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.9355
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.9093
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.8831
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.8568
# Epoch 18/50
# 5/5 [==============================] - 0s 76ms/step - loss: 115.8306
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.8044
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.7783
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.7524
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.7266
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.7009
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.6754
# Epoch 25/50
# 5/5 [==============================] - 0s 74ms/step - loss: 115.6503
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.6253
# Epoch 27/50
# 5/5 [==============================] - 0s 78ms/step - loss: 115.6002
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.5749
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.5495
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.5241
# Epoch 31/50
# 5/5 [==============================] - 0s 77ms/step - loss: 115.4989
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.4739
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.4489
# Epoch 34/50
# 5/5 [==============================] - 0s 74ms/step - loss: 115.4240
# Epoch 35/50
# 5/5 [==============================] - 0s 76ms/step - loss: 115.3989
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.3737
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.3485
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.3233
# Epoch 39/50
# 5/5 [==============================] - 0s 76ms/step - loss: 115.2982
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.2731
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.2480
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.2229
# Epoch 43/50
# 5/5 [==============================] - 0s 78ms/step - loss: 115.1976
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.1722
# Epoch 45/50
# 5/5 [==============================] - 0s 77ms/step - loss: 115.1468
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.1214
# Epoch 47/50
# 5/5 [==============================] - 0s 77ms/step - loss: 115.0959
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.0703
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 115.0447
# Epoch 50/50
# 5/5 [==============================] - 0s 74ms/step - loss: 115.0189
# Epoch 0 Loss: 115.01890563964844
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 114.9931
# Epoch 2/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.9670
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.9409
# Epoch 4/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.9148
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.8888
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.8627
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.8366
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.8105
# Epoch 9/50
# 5/5 [==============================] - 0s 74ms/step - loss: 114.7843
# Epoch 10/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.7581
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.7319
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.7057
# Epoch 13/50
# 5/5 [==============================] - 0s 74ms/step - loss: 114.6794
# Epoch 14/50
# 5/5 [==============================] - 0s 78ms/step - loss: 114.6530
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.6266
# Epoch 16/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.6002
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.5737
# Epoch 18/50
# 5/5 [==============================] - 0s 74ms/step - loss: 114.5471
# Epoch 19/50
# 5/5 [==============================] - 0s 78ms/step - loss: 114.5206
# Epoch 20/50
# 5/5 [==============================] - 0s 74ms/step - loss: 114.4941
# Epoch 21/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.4677
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.4413
# Epoch 23/50
# 5/5 [==============================] - 0s 77ms/step - loss: 114.4148
# Epoch 24/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.3884
# Epoch 25/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.3619
# Epoch 26/50
# 5/5 [==============================] - 0s 77ms/step - loss: 114.3354
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.3089
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.2823
# Epoch 29/50
# 5/5 [==============================] - 0s 77ms/step - loss: 114.2557
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.2290
# Epoch 31/50
# 5/5 [==============================] - 0s 77ms/step - loss: 114.2023
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.1756
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.1487
# Epoch 34/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.1217
# Epoch 35/50
# 5/5 [==============================] - 0s 76ms/step - loss: 114.0946
# Epoch 36/50
# 5/5 [==============================] - 0s 74ms/step - loss: 114.0675
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.0404
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 114.0132
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.9860
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.9587
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.9314
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.9041
# Epoch 43/50
# 5/5 [==============================] - 0s 77ms/step - loss: 113.8768
# Epoch 44/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.8496
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.8223
# Epoch 46/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.7950
# Epoch 47/50
# 5/5 [==============================] - 0s 77ms/step - loss: 113.7678
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.7405
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.7132
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.6859
# Epoch 0 Loss: 113.68592834472656
# Epoch 1/50
# 5/5 [==============================] - 0s 71ms/step - loss: 113.6586
# Epoch 2/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.6312
# Epoch 3/50
# 5/5 [==============================] - 0s 74ms/step - loss: 113.6038
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 113.5763
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.5488
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.5213
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.4937
# Epoch 8/50
# 5/5 [==============================] - 0s 74ms/step - loss: 113.4662
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.4386
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.4109
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.3831
# Epoch 12/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.3553
# Epoch 13/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.3274
# Epoch 14/50
# 5/5 [==============================] - 0s 76ms/step - loss: 113.2996
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.2719
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.2440
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.2163
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.1886
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.1607
# Epoch 20/50
# 5/5 [==============================] - 0s 77ms/step - loss: 113.1329
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.1049
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.0769
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 113.0488
# Epoch 24/50
# 5/5 [==============================] - 0s 77ms/step - loss: 113.0207
# Epoch 25/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.9925
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.9643
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.9361
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.9079
# Epoch 29/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.8797
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.8514
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.8230
# Epoch 32/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.7946
# Epoch 33/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.7663
# Epoch 34/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.7379
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.7096
# Epoch 36/50
# 5/5 [==============================] - 0s 77ms/step - loss: 112.6812
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.6529
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.6245
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.5962
# Epoch 40/50
# 5/5 [==============================] - 0s 77ms/step - loss: 112.5677
# Epoch 41/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.5393
# Epoch 42/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.5109
# Epoch 43/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.4827
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.4546
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.4265
# Epoch 46/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.3984
# Epoch 47/50
# 5/5 [==============================] - 0s 77ms/step - loss: 112.3703
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.3422
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.3141
# Epoch 50/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.2860
# Epoch 0 Loss: 112.28597259521484
# Epoch 1/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.2578
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.2297
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.2016
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.1734
# Epoch 5/50
# 5/5 [==============================] - 0s 76ms/step - loss: 112.1453
# Epoch 6/50
# 5/5 [==============================] - 0s 74ms/step - loss: 112.1172
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.0893
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.0613
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.0333
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 112.0055
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.9777
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.9500
# Epoch 13/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.9223
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.8946
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.8670
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.8393
# Epoch 17/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.8117
# Epoch 18/50
# 5/5 [==============================] - 0s 74ms/step - loss: 111.7841
# Epoch 19/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.7565
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.7290
# Epoch 21/50
# 5/5 [==============================] - 0s 76ms/step - loss: 111.7016
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.6742
# Epoch 23/50
# 5/5 [==============================] - 0s 74ms/step - loss: 111.6469
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.6197
# Epoch 25/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.5926
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.5655
# Epoch 27/50
# 5/5 [==============================] - 0s 74ms/step - loss: 111.5386
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.5117
# Epoch 29/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.4849
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.4582
# Epoch 31/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.4316
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.4050
# Epoch 33/50
# 5/5 [==============================] - 0s 76ms/step - loss: 111.3784
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.3519
# Epoch 35/50
# 5/5 [==============================] - 0s 76ms/step - loss: 111.3255
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.2990
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.2725
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.2461
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.2198
# Epoch 40/50
# 5/5 [==============================] - 0s 74ms/step - loss: 111.1936
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.1674
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.1414
# Epoch 43/50
# 5/5 [==============================] - 0s 77ms/step - loss: 111.1153
# Epoch 44/50
# 5/5 [==============================] - 0s 74ms/step - loss: 111.0893
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.0633
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.0374
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 111.0116
# Epoch 48/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.9859
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.9603
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.9347
# Epoch 0 Loss: 110.9347152709961
# Epoch 1/50
# 5/5 [==============================] - 0s 73ms/step - loss: 110.9092
# Epoch 2/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.8838
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.8584
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.8331
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.8079
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.7828
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.7578
# Epoch 8/50
# 5/5 [==============================] - 0s 78ms/step - loss: 110.7328
# Epoch 9/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.7079
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.6829
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.6580
# Epoch 12/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.6331
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.6082
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.5833
# Epoch 15/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.5583
# Epoch 16/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.5333
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.5082
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.4829
# Epoch 19/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.4574
# Epoch 20/50
# 5/5 [==============================] - 0s 76ms/step - loss: 110.4317
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.4059
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.3808
# Epoch 23/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.3563
# Epoch 24/50
# 5/5 [==============================] - 0s 77ms/step - loss: 110.3322
# Epoch 25/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.3083
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.2843
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.2604
# Epoch 28/50
# 5/5 [==============================] - 0s 78ms/step - loss: 110.2366
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.2132
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.1902
# Epoch 31/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.1681
# Epoch 32/50
# 5/5 [==============================] - 0s 76ms/step - loss: 110.1476
# Epoch 33/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.1282
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.1093
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.0866
# Epoch 36/50
# 5/5 [==============================] - 0s 76ms/step - loss: 110.0594
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 110.0290
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 110.0010
# Epoch 39/50
# 5/5 [==============================] - 0s 77ms/step - loss: 109.9786
# Epoch 40/50
# 5/5 [==============================] - 0s 77ms/step - loss: 109.9600
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.9411
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.9185
# Epoch 43/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.8921
# Epoch 44/50
# 5/5 [==============================] - 0s 76ms/step - loss: 109.8653
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.8416
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.8210
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.8015
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 109.7805
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.7573
# Epoch 50/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.7328
# Epoch 0 Loss: 109.73280334472656
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 109.7085
# Epoch 2/50
# 5/5 [==============================] - 0s 77ms/step - loss: 109.6858
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.6646
# Epoch 4/50
# 5/5 [==============================] - 0s 74ms/step - loss: 109.6440
# Epoch 5/50
# 5/5 [==============================] - 0s 76ms/step - loss: 109.6231
# Epoch 6/50
# 5/5 [==============================] - 0s 76ms/step - loss: 109.6014
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 109.5787
# Epoch 8/50
# 5/5 [==============================] - 0s 74ms/step - loss: 109.5556
# Epoch 9/50
# ...
# 5/5 [==============================] - 0s 75ms/step - loss: 86.3915
# Epoch 33/50
# 5/5 [==============================] - 0s 77ms/step - loss: 86.7546
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 87.2573
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 87.7391
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 88.2915
# Epoch 37/50
# 5/5 [==============================] - 0s 76ms/step - loss: 88.5372
# Epoch 38/50
# 5/5 [==============================] - 0s 78ms/step - loss: 88.5804
# Epoch 39/50
# 5/5 [==============================] - 0s 76ms/step - loss: 88.0208
# Epoch 40/50
# 5/5 [==============================] - 0s 74ms/step - loss: 87.1845
# Epoch 41/50
# 5/5 [==============================] - 0s 76ms/step - loss: 86.1821
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.4796
# Epoch 43/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2833
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.5508
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.0298
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.3950
# Epoch 47/50
# 5/5 [==============================] - 0s 78ms/step - loss: 86.4912
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.2290
# Epoch 49/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.8034
# Epoch 50/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.4200
# Epoch 0 Loss: 85.42003631591797
# Epoch 1/50
# 5/5 [==============================] - 0s 73ms/step - loss: 85.2483
# Epoch 2/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3032
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.4964
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.7000
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7965
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7735
# Epoch 7/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.6264
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.4434
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2876
# Epoch 10/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.2075
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2103
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2723
# Epoch 13/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.3509
# Epoch 14/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.4200
# Epoch 15/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.4539
# Epoch 16/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.4476
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.4099
# Epoch 18/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.3516
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2897
# Epoch 20/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.2331
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1891
# Epoch 22/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.1595
# Epoch 23/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.1465
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1438
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.1480
# Epoch 26/50
# 5/5 [==============================] - 0s 78ms/step - loss: 85.1599
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1744
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1947
# Epoch 29/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.2194
# Epoch 30/50
# 5/5 [==============================] - 0s 78ms/step - loss: 85.2557
# Epoch 31/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.2995
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.3566
# Epoch 33/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.4274
# Epoch 34/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.5223
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.6366
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7970
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.9812
# Epoch 38/50
# 5/5 [==============================] - 0s 78ms/step - loss: 86.2362
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.5007
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.8306
# Epoch 41/50
# 5/5 [==============================] - 0s 76ms/step - loss: 87.0862
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 87.3339
# Epoch 43/50
# 5/5 [==============================] - 0s 76ms/step - loss: 87.3377
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 87.2090
# Epoch 45/50
# 5/5 [==============================] - 0s 77ms/step - loss: 86.7838
# Epoch 46/50
# 5/5 [==============================] - 0s 77ms/step - loss: 86.2600
# Epoch 47/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.6895
# Epoch 48/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.2649
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0723
# Epoch 50/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.1215
# Epoch 0 Loss: 85.12149047851562
# Epoch 1/50
# 5/5 [==============================] - 0s 71ms/step - loss: 85.3262
# Epoch 2/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.5776
# Epoch 3/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.7861
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.8603
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.8173
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.6589
# Epoch 7/50
# 5/5 [==============================] - 0s 78ms/step - loss: 85.4596
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2611
# Epoch 9/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1110
# Epoch 10/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.0300
# Epoch 11/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0185
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0613
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1332
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2124
# Epoch 15/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.2806
# Epoch 16/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3370
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.3629
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.3748
# Epoch 19/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3603
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.3402
# Epoch 21/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3014
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2670
# Epoch 23/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.2251
# Epoch 24/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.1843
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.1427
# Epoch 26/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.1101
# Epoch 27/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.0805
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0581
# Epoch 29/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0416
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0313
# Epoch 31/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.0251
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0255
# Epoch 33/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.0356
# Epoch 34/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0551
# Epoch 35/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.0855
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1397
# Epoch 37/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2154
# Epoch 38/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3380
# Epoch 39/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.5143
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7833
# Epoch 41/50
# 5/5 [==============================] - 0s 74ms/step - loss: 86.1423
# Epoch 42/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.6824
# Epoch 43/50
# 5/5 [==============================] - 0s 78ms/step - loss: 87.3139
# Epoch 44/50
# 5/5 [==============================] - 0s 76ms/step - loss: 88.1772
# Epoch 45/50
# 5/5 [==============================] - 0s 75ms/step - loss: 88.9112
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 89.5727
# Epoch 47/50
# 5/5 [==============================] - 0s 76ms/step - loss: 89.3977
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 88.6152
# Epoch 49/50
# 5/5 [==============================] - 0s 76ms/step - loss: 87.0707
# Epoch 50/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.6382
# Epoch 0 Loss: 85.63819885253906
# Epoch 1/50
# 5/5 [==============================] - 0s 71ms/step - loss: 84.9335
# Epoch 2/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.1749
# Epoch 3/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.9474
# Epoch 4/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.5535
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.6160
# Epoch 6/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.0506
# Epoch 7/50
# 5/5 [==============================] - 0s 78ms/step - loss: 85.3301
# Epoch 8/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.9041
# Epoch 9/50
# 5/5 [==============================] - 0s 74ms/step - loss: 84.9715
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.3556
# Epoch 11/50
# 5/5 [==============================] - 0s 79ms/step - loss: 85.6957
# Epoch 12/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7617
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.5002
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.1336
# Epoch 15/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.8805
# Epoch 16/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.8593
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0129
# Epoch 18/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.1997
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2935
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2316
# Epoch 21/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0778
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.9111
# Epoch 23/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.8111
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8066
# Epoch 25/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8710
# Epoch 26/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.9568
# Epoch 27/50
# 5/5 [==============================] - 0s 77ms/step - loss: 85.0159
# Epoch 28/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.0256
# Epoch 29/50
# 5/5 [==============================] - 0s 78ms/step - loss: 84.9840
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.9160
# Epoch 31/50
# 5/5 [==============================] - 0s 77ms/step - loss: 84.8426
# Epoch 32/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7868
# Epoch 33/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7581
# Epoch 34/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.7524
# Epoch 35/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7672
# Epoch 36/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7903
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 84.8152
# Epoch 38/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8356
# Epoch 39/50
# 5/5 [==============================] - 0s 78ms/step - loss: 84.8471
# Epoch 40/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8504
# Epoch 41/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8480
# Epoch 42/50
# 5/5 [==============================] - 0s 77ms/step - loss: 84.8396
# Epoch 43/50
# 5/5 [==============================] - 0s 77ms/step - loss: 84.8280
# Epoch 44/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8117
# Epoch 45/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.7944
# Epoch 46/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7787
# Epoch 47/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.7651
# Epoch 48/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7543
# Epoch 49/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7466
# Epoch 50/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.7422
# Epoch 0 Loss: 84.74220275878906
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 84.7408
# Epoch 2/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.7418
# Epoch 3/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7483
# Epoch 4/50
# 5/5 [==============================] - 0s 77ms/step - loss: 84.7607
# Epoch 5/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.7821
# Epoch 6/50
# 5/5 [==============================] - 0s 74ms/step - loss: 84.8163
# Epoch 7/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.8719
# Epoch 8/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.9541
# Epoch 9/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.0831
# Epoch 10/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.2654
# Epoch 11/50
# 5/5 [==============================] - 0s 74ms/step - loss: 85.5448
# Epoch 12/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.9170
# Epoch 13/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.4601
# Epoch 14/50
# 5/5 [==============================] - 0s 75ms/step - loss: 87.0895
# Epoch 15/50
# 5/5 [==============================] - 0s 74ms/step - loss: 87.9160
# Epoch 16/50
# 5/5 [==============================] - 0s 77ms/step - loss: 88.5532
# Epoch 17/50
# 5/5 [==============================] - 0s 75ms/step - loss: 89.0994
# Epoch 18/50
# 5/5 [==============================] - 0s 75ms/step - loss: 88.8351
# Epoch 19/50
# 5/5 [==============================] - 0s 75ms/step - loss: 88.0312
# Epoch 20/50
# 5/5 [==============================] - 0s 75ms/step - loss: 86.5986
# Epoch 21/50
# 5/5 [==============================] - 0s 76ms/step - loss: 85.3054
# Epoch 22/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.6870
# Epoch 23/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.9079
# Epoch 24/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.6066
# Epoch 25/50
# 5/5 [==============================] - 0s 76ms/step - loss: 86.1829
# Epoch 26/50
# 5/5 [==============================] - 0s 76ms/step - loss: 86.2604
# Epoch 27/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.7573
# Epoch 28/50
# 5/5 [==============================] - 0s 75ms/step - loss: 85.0808
# Epoch 29/50
# 5/5 [==============================] - 0s 76ms/step - loss: 84.6634
# Epoch 30/50
# 5/5 [==============================] - 0s 75ms/step - loss: 84.6936

# %%
# import matplotlib.pyplot as plt
# preds = mt.predict(images,'test')

# print(preds.shape)
# x = mt.predict(images, image_names)

# plt.imshow(x[0,:,:,:])


# for j, pred in enumerate(preds):
#   cv2.imwrite( str(env.path / 'data' / 'test_color' / f"{image_names[j]}.png"), y)

# %%
mt.model.model.history.history['loss'][-1]

# %%
input = keras.layers.Input(shape=(5, 5, 3))

depad_filter_size = 3
depad_kernel = np.zeros([depad_filter_size, depad_filter_size, 3, 3])
center = int(depad_kernel.shape[0]/2)

for i in range(3):
  depad_kernel[center, center,i,i] = 1

depad_bias = np.zeros([3])

out = keras.layers.Conv2D(3, (depad_filter_size, depad_filter_size), strides=(1,1),
                                weights=[depad_kernel, depad_bias], trainable=False)(input)


model = keras.Model(inputs=input, outputs=out)

model.compile(keras.optimizers.Adam(), 'mean_squared_error')

model.summary()

x = np.random.randn(1,5,5,3)
y = model.predict(x)
print((y - x[:,1:-1,1:-1,:]).sum())

print(x[0,:,:,0])
print(y[0,:,:,0])

print(x[0,:,:,1])
print(y[0,:,:,1])
